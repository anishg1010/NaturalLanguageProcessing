# %%
import re
text = "There are 45 students and 12 laptops."
numbers = re.findall(r'\d+', text)
print(numbers)
# Out:
# ['45', '12']

# %%
email = "gawareanish@yahoo.com"
n1 = re.findall(r'\w+@\w+\.\w+', email)
print(n1)
# Out:
# ['gawareanish@yahoo.com']

# %%
t1 = "Hello!!! Welcome to NLP, class #2026."
n2 = re.findall(r'[\a-zA-Z+ \a-zA-Z+ ]', t1)

# %%
import nltk

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Anish\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Anish\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
textt = "This is a sample sentence, showing off the stop words filtration."
text3 = "This is another example of a sentence with stop words."
text4 = "My name is Anish and I am learning NLP."
text5 = "NLP is a fascinating field of study that combines linguistics and computer science."
text6 = "Stop words are common words that are usually filtered out in text processing tasks."
text7 = "Why do we need to remove stop words from our text data?"

# %%
tokens = word_tokenize(textt)
print(tokens)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']

# %%
filtered_words = {
    word for word in tokens if word not in stopwords.words('english')
}
print(filtered_words)
# Out:
# {'This', 'words', ',', '.', 'sample', 'showing', 'stop', 'sentence', 'filtration'}

# %%
tokens = word_tokenize(text3)
print(tokens)

filtered_words3 = {
    word for word in tokens if word not in stopwords.words('english')
}
print(filtered_words3)
# Out:
# ['This', 'is', 'another', 'example', 'of', 'a', 'sentence', 'with', 'stop', 'words', '.']
# {'This', 'words', 'another', 'example', '.', 'stop', 'sentence'}

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk.stem import SnowballStemmer

# %%
#objects
porter = PorterStemmer()
lancaster = LancasterStemmer()
snowball = SnowballStemmer('english')

# %%
words = {
    "running",
    "studies",
    "happily",
    "university",
    "relational",
    "relationally",
    "happiness"
}

# %%
# Apply stemming
print(f"{'Word':15} {'Porter':15} {'Lancaster':15} {'Snowball':15}")
print("-" * 60)

for word in words:
    print(f"{word:15} "
          f"{porter.stem(word):15} "
          f"{lancaster.stem(word):15} "
          f"{snowball.stem(word):15}")
# Out:
# Word            Porter          Lancaster       Snowball
# ------------------------------------------------------------
# running         run             run             run
# university      univers         univers         univers
# happily         happili         happy           happili
# relational      relat           rel             relat
# relationally    relat           rel             relate
# happiness       happi           happy           happi
# studies         studi           study           studi

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: C:\Users\Anish\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()
print(f"{'Word':15} {'WNL':15}")
print("-" * 60)

for word in words:
    print(f"{word:15} "
          f"{lemmatizer.lemmatize(word)}"
    )

# %%
#nltk.download('wordnet')

# %%
#nltk.download('omw-1.4')

# %%
lemmatizer = WordNetLemmatizer()
words = {
    "running",
    "studies",
    "happily",
    "university",
    "relational",
    "relationally",
    "happiness",
    "better",
    "wolves",
    "children",
    "delayed",
    "tracking"
}

# %%
print(f"{'Word':15} {'WNL':15}")
print("-" * 60)

for word in words:
    print(f"{word:15} "
          f"{lemmatizer.lemmatize(word)}"
    )
# Out:
# Word            WNL
# ------------------------------------------------------------
# happiness       happiness
# relationally    relationally
# studies         study
# delayed         delayed
# happily         happily
# wolves          wolf
# university      university
# relational      relational
# better          better
# tracking        tracking
# running         running
# children        child

# %%
pip install spacy
# Out:
# ...
#   Using cached typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# ...
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.4 MB 1.3 MB/s eta 0:00:12
#    -- ------------------------------------- 1.0/15.4 MB 1.4 MB/s eta 0:00:10
#    --- ------------------------------------ 1.3/15.4 MB 1.5 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.6/15.4 MB 1.5 MB/s eta 0:00:10
#    ----- ---------------------------------- 2.1/15.4 MB 1.6 MB/s eta 0:00:09
#    ------- -------------------------------- 2.9/15.4 MB 1.9 MB/s eta 0:00:07
# ...

# %%
import spacy
# Out:
# STDOUT: Collecting en-core-web-sm==3.8.0
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - ------------------------------------- 0.5/12.8 MB 932.9 kB/s eta 0:00:14
#      -- ------------------------------------ 0.8/12.8 MB 958.5 kB/s eta 0:00:13
#      --- ------------------------------------ 1.0/12.8 MB 1.1 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.3/12.8 MB 1.1 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.6/12.8 MB 1.2 MB/s eta 0:00:10
#      ----- ---------------------------------- 1.8/12.8 MB 1.2 MB/s eta 0:00:10
#      ------ --------------------------------- 2.1/12.8 MB 1.2 MB/s eta 0:00:09
#      ------- -------------------------------- 2.4/12.8 MB 1.2 MB/s eta 0:00:09
#      ------- -------------------------------- 2.4/12.8 MB 1.2 MB/s eta 0:00:09
# ...

# %%
#nlp = spacy.load('en_core_web_sm')
#import spacy

lang = "en"   # change to "de" for German

if lang == "de":
    nlp = spacy.load("de_core_news_sm")
else:
    nlp = spacy.load("en_core_web_sm")

#doc = nlp("This is a sample sentence.")
#print([token.text for token in doc])

# %%
text7 = """1. OMGGG 😭😭 my flight from FRA → DEL got delayed AGAIN!!! #Lufthansa @airporthelp
2. The baggage tracking system isn't working properly after the latest update :(
3. GREAT SERVICE!!! waited ONLY 5 hours for support 👏👏 #sarcasm
4. Sehr schlechter Kundenservice!!! Niemand antwortet auf meine Emails.
5. Flight AI-202 cancelled 😡 Refund still pending after 3 weeks!!!
6. Visit www.airlinehelp.com/refund to check your refund status.
7. I can’t login to the app since update v2.4.1 pls fix ASAP!!!!
8. 😠😡
9. Seats were fine but food was meh...

10. SUPPORT SUPPORT SUPPORT!!!!!!!
"""

# %%
# Lemmatization with 2 columns
import pandas as pd

doc = nlp(text7)

# Create data for DataFrame
data = {
    'Original': [token.text for token in doc],
    'Lemmatized': [token.lemma_ for token in doc]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the table
print(df.to_string(index=False))
# Out:
#                   Original                 Lemmatized
#                          1                          1
#                          .                          .
#                      OMGGG                      omggg
#                          😭                          😭
#                          😭                          😭
#                         my                         my
#                     flight                     flight
#                       from                       from
#                        FRA                        FRA
#                          →                          →
#                        DEL                        DEL
#                        got                        get
#                    delayed                      delay
#                      AGAIN                      again
#                          !                          !
#                          !                          !
# ...

# %%
import re

text = """
https://twitter.com/teslarati
https://twitter.com/dummy_tesla
https://twitter.com/dummy_2_tesla
"""

pattern = r'https://twitter\.com/([A-Za-z0-9_]+)'

handles = re.findall(pattern, text)

print(handles)
# Out:
# ['teslarati', 'dummy_tesla', 'dummy_2_tesla']

# %% [markdown]
# #Home Assignments
# ##Text Preprocessing Pipeline

# %%
texttast = """
Natural Language Processing, also known as NLP, is one of the most important areas of Artificial Intelligence.
Today, companies use NLP in chatbots, search engines, recommendation systems, social media analytics,
customer feedback analysis, automatic translation, and voice assistants.
 
In 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
online forms, tweets, product comments, and support tickets. However, this text data is often messy.
For example, a customer may write: "I LOVE this product!!! Visit https://example.com/product123 #Amazing #AI".
Another user may write: "The service was not good... I waited 45 minutes and no one replied."
 
Before applying machine learning or deep learning models, we need to clean and prepare the text.
This step is called text preprocessing. It may include converting text to lowercase, removing URLs,
removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
stemming, lemmatization, and sometimes removing emojis or special characters.
 
Good preprocessing can improve the quality of NLP models. However, preprocessing should be done carefully.
For example, removing the word "not" from the sentence "I am not happy" can change the meaning completely.
Similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
can contain useful information about topics, opinions, or trends.
 
Your task is to build a complete NLP preprocessing pipeline for this text.
You should clean the text step by step and observe how the output changes after each step.
"""

# %%
#1. Clean emojis and hashtags
#2. Lowercase
#3. Tokenize
#4. Remove stop words
#5. Lemmatize
#6. Bonus for using multiple libraries (NLTK, spaCy).

# %%
text_step1 = re.sub(r'http\S+|www\S+|https\S+', '', texttast, flags=re.MULTILINE)
text_step1 = re.sub(r'#\w+', '', text_step1)
print(text_step1)
# Out:
# Step 1 - After removing URLs and hashtags:
#
# Natural Language Processing, also known as NLP, is one of the most important areas of Artificial Intelligence.
# Today, companies use NLP in chatbots, search engines, recommendation systems, social media analytics,
# customer feedback analysis, automatic translation, and voice assistants.
#
# In 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
# online forms, tweets, product comments, and support tickets. However, this text data is often messy.
# For example, a customer may write: "I LOVE this product!!! Visit   ".
# Another user may write: "The service was not good... I waited 45 minutes and no one replied."
#
# Before applying machine learning or deep learning models, we need to clean and prepare the text.
# This step is called text preprocessing. It may include converting text to lowercase, removing URLs,
# ...

# %%
text_step2 = text_step1.lower()
print(text_step2)
# Out:
# Step 2 - After lowercase:
#
# natural language processing, also known as nlp, is one of the most important areas of artificial intelligence.
# today, companies use nlp in chatbots, search engines, recommendation systems, social media analytics,
# customer feedback analysis, automatic translation, and voice assistants.
#
# in 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
# online forms, tweets, product comments, and support tickets. however, this text data is often messy.
# for example, a customer may write: "i love this product!!! visit   ".
# another user may write: "the service was not good... i waited 45 minutes and no one replied."
#
# before applying machine learning or deep learning models, we need to clean and prepare the text.
# this step is called text preprocessing. it may include converting text to lowercase, removing urls,
# removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
# ...

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: C:\Users\Anish\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from nltk.tokenize import word_tokenize
#nltk.download('punkt_tab')

# %%
text_step3 = word_tokenize(text_step2)
print(text_step3)
# Out:
# ['natural', 'language', 'processing', ',', 'also', 'known', 'as', 'nlp', ',', 'is', 'one', 'of', 'the', 'most', 'important', 'areas', 'of', 'artificial', 'intelligence', '.', 'today', ',', 'companies', 'use', 'nlp', 'in', 'chatbots', ',', 'search', 'engines', ',', 'recommendation', 'systems', ',', 'social', 'media', 'analytics', ',', 'customer', 'feedback', 'analysis', ',', 'automatic', 'translation', ',', 'and', 'voice', 'assistants', '.', 'in', '2026', ',', 'many', 'organizations', 'are', 'collecting', 'huge', 'amounts', 'of', 'text', 'data', 'from', 'websites', ',', 'emails', ',', 'reviews', ',', 'online', 'forms', ',', 'tweets', ',', 'product', 'comments', ',', 'and', 'support', 'tickets', '.', 'however', ',', 'this', 'text', 'data', 'is', 'often', 'messy', '.', 'for', 'example', ',', 'a', 'customer', 'may', 'write', ':', '``', 'i', 'love', 'this', 'product', '!', '!', '!', 'visit', '``', '.', 'another', 'user', 'may', 'write', ':', '``', 'the', 'service', 'was', 'not', 'good', '
# ...

# %%
from nltk.corpus import stopwords
#nltk.download('stopwords')

# %%
text_step4 = {
    word for word in text_step3 if word not in stopwords.words('english')
}
print(text_step4)
# Out:
# {'preprocessing', 'social', 'sentence', 'numbers', 'carefully', 'topics', 'improve', 'websites', 'tweets', 'service', 'intelligence', 'product', '!', '``', 'processing', 'huge', 'characters', 'tokenizing', 'need', 'done', 'applying', 'include', 'lowercase', '.', 'search', 'data', 'online', 'another', ':', 'clean', 'also', 'happy', 'words', 'stop', 'often', 'converting', 'many', 'observe', 'companies', 'models', 'prepare', 'translation', 'pipeline', 'sentences', "''", 'automatic', 'output', 'support', 'organizations', 'emails', 'language', 'machine', 'forms', 'today', 'text', 'useful', 'love', 'word', 'stemming', 'chatbots', 'messy', 'changes', 'customer', 'reviews', 'write', 'comments', 'engines', 'systems', 'user', 'always', 'similarly', 'may', 'voice', 'special', 'trends', 'called', 'important', 'good', 'tickets', 'however', 'step', 'analysis', 'replied', 'task', 'quality', 'feedback', 'change', 'areas', 'use', 'build', 'completely', 'known', 'emojis', 'learning', 'sometimes', 'nat
# ...

# %%
#from nltk.stem import WordNetLemmatizer
#nltk.download('wordnet')
#nltk.download('omw-1.4')

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print("-" * 50)
print(f"{'Word':20} {'Lemma':20}")
print("-" * 50)

for word in text_step4:
    print(f"{word:20} {lemmatizer.lemmatize(word):20}")
# Out:
# --------------------------------------------------
# Word                 Lemma
# --------------------------------------------------
# preprocessing        preprocessing
# social               social
# sentence             sentence
# numbers              number
# carefully            carefully
# topics               topic
# improve              improve
# websites             website
# tweets               tweet
# service              service
# intelligence         intelligence
# product              product
# !                    !
# ``                   ``
# processing           processing
# huge                 huge
# characters           character
# tokenizing           tokenizing
# need                 need
# done                 done
# applying             applying
# include              include
# lowercase            lowercase
# .                    .
# search               search
# data                 data
# online               online
# another              another
# ...
